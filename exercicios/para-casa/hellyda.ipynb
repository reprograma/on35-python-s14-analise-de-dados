# %%
import pandas as pd

# %%
df_pedidos = pd.read_csv('dados/olist_orders_dataset.csv')
df_pedidos
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df_itens_pedido = pd.read_csv('dados/olist_order_items_dataset.csv')
df_itens_pedido
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df_olist_pedidos = pd.merge(df_pedidos, df_itens_pedido, on=['order_id'], how='inner')
df_olist_pedidos
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112645  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112646  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112647  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112648  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112649  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df_consumidor = pd.read_csv('dados/olist_customers_dataset.csv')
df_consumidor
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
df_olist_pedidos_uf = pd.merge(df_olist_pedidos, df_consumidor, on=['customer_id'], how='inner')
df_olist_pedidos_uf
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112645  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112646  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112647  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112648  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112649  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df_produto = pd.read_csv('dados/olist_products_dataset.csv')
df_produto
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
df_olist_pedidos_produtos = pd.merge(df_olist_pedidos_uf, df_produto, on=['product_id'], how='inner')

df_olist_pedidos_produtos
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112645  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112646  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112647  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112648  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112649  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df_olist_pedidos_produtos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112650 non-null  object
#  1   customer_id                    112650 non-null  object
#  2   order_status                   112650 non-null  object
#  3   order_purchase_timestamp       112650 non-null  object
#  4   order_approved_at              112635 non-null  object
#  5   order_delivered_carrier_date   111456 non-null  object
#  6   order_delivered_customer_date  110196 non-null  object
#  7   order_estimated_delivery_date  112650 non-null  object
#  8   order_item_id                  112650 non-null  int64
#  9   product_id                     112650 non-null  object
#  10  seller_id                      112650 non-null  object
#  11  shipping_limit_date            112650 non-null  object
# ...

# %%
df_reduzido  = df_olist_pedidos_produtos[['order_id', 'order_status', 'price', 'freight_value','customer_state','product_category_name']]
df_reduzido
# Out:
#                                 order_id order_status   price  freight_value  \
# 0       e481f51cbdc54678b7cc49136f2d6af7    delivered   29.99           8.72
# 1       53cdb2fc8bc7dce0b6741e2150273451    delivered  118.70          22.76
# 2       47770eb9100c2d0c44946d9cf07ec65d    delivered  159.90          19.22
# 3       949d5b44dbf5de918fe9c16f97b45f8a    delivered   45.00          27.20
# 4       ad21c59c0840e6cb83a9ceb5573f8159    delivered   19.90           8.72
# ...                                  ...          ...     ...            ...
# 112645  63943bddc261676b46f01ca7ac2f7bd8    delivered  174.90          20.10
# 112646  83c1379a015df1e13d02aae0204711ab    delivered  205.99          65.02
# 112647  11c177c8e97725db2631073c19f07b62    delivered  179.99          40.59
# 112648  11c177c8e97725db2631073c19f07b62    delivered  179.99          40.59
# 112649  66dea50a8b16d9b4dee7af250b4be1a5    delivered   68.50          18.36
#
# ...

# %%
df_reduzido.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   order_id               112650 non-null  object
#  1   order_status           112650 non-null  object
#  2   price                  112650 non-null  float64
#  3   freight_value          112650 non-null  float64
#  4   customer_state         112650 non-null  object
#  5   product_category_name  111047 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 5.2+ MB

# %%
df_reduzido['order_status'].unique()
# Out:
# array(['delivered', 'invoiced', 'shipped', 'processing', 'canceled',
#        'unavailable', 'approved'], dtype=object)

# %%
df_reduzido = df_reduzido.loc[df_reduzido['order_status'] == 'delivered']

# Mostra o DataFrame 'df_pedidos' na tela, agora com apenas os pedidos entregues.
# 'df_pedidos' é o nome do DataFrame que queremos mostrar.
df_reduzido
# Out:
#                                 order_id order_status   price  freight_value  \
# 0       e481f51cbdc54678b7cc49136f2d6af7    delivered   29.99           8.72
# 1       53cdb2fc8bc7dce0b6741e2150273451    delivered  118.70          22.76
# 2       47770eb9100c2d0c44946d9cf07ec65d    delivered  159.90          19.22
# 3       949d5b44dbf5de918fe9c16f97b45f8a    delivered   45.00          27.20
# 4       ad21c59c0840e6cb83a9ceb5573f8159    delivered   19.90           8.72
# ...                                  ...          ...     ...            ...
# 112645  63943bddc261676b46f01ca7ac2f7bd8    delivered  174.90          20.10
# 112646  83c1379a015df1e13d02aae0204711ab    delivered  205.99          65.02
# 112647  11c177c8e97725db2631073c19f07b62    delivered  179.99          40.59
# 112648  11c177c8e97725db2631073c19f07b62    delivered  179.99          40.59
# 112649  66dea50a8b16d9b4dee7af250b4be1a5    delivered   68.50          18.36
#
# ...

# %%
df_reduzido.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 110197 entries, 0 to 112649
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   order_id               110197 non-null  object
#  1   order_status           110197 non-null  object
#  2   price                  110197 non-null  float64
#  3   freight_value          110197 non-null  float64
#  4   customer_state         110197 non-null  object
#  5   product_category_name  108660 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 5.9+ MB

# %%
df_reduzido.to_csv('base_final_s14_olist.csv', index=False)

# %%
df_reduzido.describe().T
# Out:
#                   count        mean         std   min    25%    50%     75%  \
# price          110197.0  119.980563  182.299446  0.85  39.90  74.90  134.17
# freight_value  110197.0   19.948598   15.698136  0.00  13.08  16.26   21.15
#
#                    max
# price          6735.00
# freight_value   409.68

# %%
df_estados = df_reduzido.groupby('customer_state').agg({'order_id': 'nunique'})
df_estados.sort_values(by='order_id', ascending=False)
# Out:
#                 order_id
# customer_state
# SP                 40501
# RJ                 12350
# MG                 11354
# RS                  5345
# PR                  4923
# SC                  3546
# BA                  3256
# DF                  2080
# ES                  1995
# GO                  1957
# PE                  1593
# CE                  1279
# PA                   946
# MT                   886
# MA                   717
# MS                   701
# PB                   517
# PI                   476
# RN                   474
# AL                   397
# SE                   335
# TO                   274
# RO                   243
# AM                   145
# AC                    80
# AP                    67
# RR                    41

# %%
df_categorias = df_reduzido.groupby('product_category_name').agg({'order_id': 'nunique'})
df_categorias.sort_values(by='order_id', ascending=False)
# Out:
#                                                order_id
# product_category_name
# cama_mesa_banho                                    9272
# beleza_saude                                       8647
# esporte_lazer                                      7530
# informatica_acessorios                             6530
# moveis_decoracao                                   6307
# ...                                                 ...
# portateis_cozinha_e_preparadores_de_alimentos        13
# cds_dvds_musicais                                    12
# fashion_roupa_infanto_juvenil                         7
# pc_gamer                                              7
# seguros_e_servicos                                    2
#
# [73 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# definir tamanho da figura
plt.figure(figsize=(12, 8))

# instanciar o tipo de plotagem, no caso, um countplot usando x como as faixas etárias
sns.countplot(data = df_reduzido,
              x = 'customer_state')

# definir texto do título e eixos x e y
plt.title('Consumo por Estado')
plt.xlabel('Estados')
plt.ylabel('Contagem')
plt.show()

# %%
plt.figure(figsize=(12, 8))

# Selecionar as 15 categorias mais frequentes
top_15_categorias = df_reduzido['product_category_name'].value_counts().nlargest(15).index

# Filtrar o DataFrame para conter apenas essas categorias
df_top_15 = df_reduzido[df_reduzido['product_category_name'].isin(top_15_categorias)]

sns.countplot(data = df_top_15, x = 'product_category_name')

plt.title('Principais categorias de Consumo')
plt.xlabel('Categorias')
plt.ylabel('Contagem')

plt.xticks(rotation=45) 
plt.show()
