# %%
import pandas as pd

# %%
df_netflix = pd.read_csv('netflix.csv')
df_netflix
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1             Basic               10  15-01-22          10-06-23
# 1           2           Premium               15  05-09-21          22-06-23
# 2           3          Standard               12  28-02-23          27-06-23
# 3           4          Standard               12  10-07-22          26-06-23
# 4           5             Basic               10  01-05-23          28-06-23
# ...       ...               ...              ...       ...               ...
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
#              Country  Age  Gender      Device Plan Duration
# 0      United States   28    Male  Smartphone       1 Month
# 1             Canada   35  Female      Tablet       1 Month
# 2     United Kingdom   42    Male    Smart TV       1 Month
# 3          Australia   51  Female      Laptop       1 Month
# 4            Germany   33    Male  Smartphone       1 Month
# ...              ...  ...     ...         ...           ...
# 2495           Spain   28  Female    Smart TV       1 Month
# 2496           Spain   33  Female    Smart TV       1 Month
# 2497   United States   38    Male      Laptop       1 Month
# 2498          Canada   48  Female      Tablet       1 Month
# 2499   United States   35  Female    Smart TV       1 Month
#
# [2500 rows x 10 columns]

# %%
df_netflix["Device"].value_counts()
# Out:
# Device
# Laptop        636
# Tablet        633
# Smartphone    621
# Smart TV      610
# Name: count, dtype: int64

# %% [markdown]
# ** 633 usuários utilizam o netflix pelo tablet

# %%
df_netflix["Device"].value_counts(normalize=True)
# Out:
# Device
# Laptop        0.2544
# Tablet        0.2532
# Smartphone    0.2484
# Smart TV      0.2440
# Name: proportion, dtype: float64

# %% [markdown]
# ** Os sistemas operacionais Laptop e Tablet estão tecnicamente empatados com 25% de usuários cada um.

# %%
df_netflix.loc[df_netflix['Age'] < 25, 'grupo_idade'] = '20-24'
df_netflix.loc[(df_netflix['Age'] >= 25) & (df_netflix['Age'] < 30), 'grupo_idade'] = '25-29'
df_netflix.loc[(df_netflix['Age'] >= 30) & (df_netflix['Age'] < 35), 'grupo_idade'] = '30-34'
df_netflix.loc[(df_netflix['Age'] >= 35) & (df_netflix['Age'] < 40), 'grupo_idade'] = '35-39'
df_netflix.loc[(df_netflix['Age'] >= 40) & (df_netflix['Age'] < 45), 'grupo_idade'] = '40-44'
df_netflix.loc[(df_netflix['Age'] >= 45) & (df_netflix['Age'] < 50), 'grupo_idade'] = '45-49'
df_netflix.loc[(df_netflix['Age'] >= 50) & (df_netflix['Age'] < 55), 'grupo_idade'] = '50-54'
df_netflix.loc[(df_netflix['Age'] >= 55) & (df_netflix['Age'] < 60), 'grupo_idade'] = '55-59'
df_netflix.loc[df_netflix['Age'] >= 60, 'grupo_idade'] = '60+'
df_netflix
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1             Basic               10  15-01-22          10-06-23
# 1           2           Premium               15  05-09-21          22-06-23
# 2           3          Standard               12  28-02-23          27-06-23
# 3           4          Standard               12  10-07-22          26-06-23
# 4           5             Basic               10  01-05-23          28-06-23
# ...       ...               ...              ...       ...               ...
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
#              Country  Age  Gender      Device Plan Duration grupo_idade
# 0      United States   28    Male  Smartphone       1 Month       25-29
# 1             Canada   35  Female      Tablet       1 Month       35-39
# 2     United Kingdom   42    Male    Smart TV       1 Month       40-44
# 3          Australia   51  Female      Laptop       1 Month       50-54
# 4            Germany   33    Male  Smartphone       1 Month       30-34
# ...              ...  ...     ...         ...           ...         ...
# 2495           Spain   28  Female    Smart TV       1 Month       25-29
# 2496           Spain   33  Female    Smart TV       1 Month       30-34
# 2497   United States   38    Male      Laptop       1 Month       35-39
# 2498          Canada   48  Female      Tablet       1 Month       45-49
# 2499   United States   35  Female    Smart TV       1 Month       35-39
#
# [2500 rows x 11 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12, 8))

sns.countplot(data = df_netflix,
              x = 'Device',
              hue = 'grupo_idade')

plt.title('Sistema operacional por faixa etária')
plt.xlabel('Faixa etária')
plt.ylabel('Contagem')

plt.legend(title = 'Faixa etária')

plt.show()

# %% [markdown]
# **  A partir da análise do gráfico de Faixa Etária, obtemos os seguintes resultados:
# 30-39 = Smart TV
# 35-39 = Smartphone
# 40-44 = Laptop
# 45-49 = Usam, quase que igualmente, tablet e smart TV
# As faixas etárias 25-29 e 50-54 seguem um padrão, pois usam, praticamente, na mesma proporção todos os sistemas operacionais envolvidos.

# %%
df_brazil = df_netflix[df_netflix['Country']=='Brazil']

# %%
plt.figure(figsize=(10, 6))

sns.countplot(data = df_brazil,
              x = 'Country',
              hue = 'Device')

plt.title('Dispositivo mais utilizado no Brasil')
plt.xlabel('País')
plt.ylabel('Contagem')

plt.legend(title = 'Dispositivos')

plt.show()
